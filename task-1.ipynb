# %%
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv('2018-12-09.csv')
df
# Out:
#             id  scraped_on  price  stock  \
# 0     11915875  2018-12-09   38.0     47
# 1     13685596  2018-12-09   36.0     70
# 2     17932160  2018-12-09   36.0    102
# 3     18879670  2018-12-09    6.0     21
# 4     19105110  2018-12-09    7.0     60
# ...        ...         ...    ...    ...
# 7903  33891284  2018-12-09   38.0     40
# 7904  33907365  2018-12-09   20.0     10
# 7905  33907369  2018-12-09   28.0     10
# 7906  33909330  2018-12-09   24.0     10
# 7907  33918322  2018-12-09   70.0     40
#
#                                               image_url         category
# 0     https://images.topshop.com/i/TopShop/TS44J82EB...            Jeans
# 1     https://images.topshop.com/i/TopShop/TS26A28FB...            Jeans
# 2     https://images.topshop.com/i/TopShop/TS44L37GB...            Jeans
# 3     https://images.topshop.com/i/TopShop/TS44T15HW...             Tops
# 4     https://images.topshop.com/i/TopShop/TS27D04HW...           Skirts
# ...

# %%
df.describe()
# Out:
#                  id        price        stock
# count  7.908000e+03  7908.000000  7908.000000
# mean   3.232795e+07    29.401433    25.649595
# std    1.501876e+06    27.591032    29.059683
# min    1.191588e+07     1.000000     0.000000
# 25%    3.185172e+07    10.000000     6.000000
# 50%    3.266623e+07    22.000000    13.000000
# 75%    3.334599e+07    39.000000    40.000000
# max    3.391832e+07   595.000000   240.000000

# %%
df.max()
# Out:
# id                                                     33918322
# scraped_on                                           2018-12-09
# price                                                       595
# stock                                                       240
# image_url     https://images.topshop.com/i/TopShop/TS63R11KB...
# dtype: object

# %%
#  id with the max price
df[df.price == df.price.max()]
# Out:
#             id  scraped_on  price  stock  \
# 7714  33798147  2018-12-09  595.0     17
#
#                                               image_url         category
# 7714  https://images.topshop.com/i/TopShop/TS07X01QC...  Jackets & Coats

# %%
df[df.stock == df.stock.max()]
# Out:
#             id  scraped_on  price  stock  \
# 82    26193597  2018-12-09   40.0    240
# 302   29370594  2018-12-09   40.0    240
# 4000  32677450  2018-12-09   42.0    240
# 4426  32788392  2018-12-09   40.0    240
#
#                                               image_url category
# 82    https://images.topshop.com/i/TopShop/TS02J26KB...    Jeans
# 302   https://images.topshop.com/i/TopShop/TS02K02MW...    Jeans
# 4000  https://images.topshop.com/i/TopShop/TS02K12PM...    Jeans
# 4426  https://images.topshop.com/i/TopShop/TS02K02PI...    Jeans

# %%
# id with the min stock value
df[df.stock == df.stock.min()]
# Out:
#             id  scraped_on  price  stock  \
# 117   27219750  2018-12-09   34.0      0
# 233   28815023  2018-12-09    4.0      0
# 428   30057295  2018-12-09   20.0      0
# 436   30091953  2018-12-09   15.0      0
# 523   30366355  2018-12-09   25.0      0
# 654   30732670  2018-12-09   10.0      0
# 826   31004149  2018-12-09   19.0      0
# 829   31009130  2018-12-09   15.0      0
# 938   31127733  2018-12-09    5.0      0
# 1040  31215740  2018-12-09   25.0      0
# 1086  31267905  2018-12-09   10.0      0
# 1359  31466810  2018-12-09    5.0      0
# 1394  31483440  2018-12-09   10.0      0
# 1448  31552201  2018-12-09   15.0      0
# 1502  31590221  2018-12-09   20.0      0
# 1559  31621660  2018-12-09    5.0      0
# 1630  31666798  2018-12-09   32.0      0
# 1796  31756821  2018-12-09   15.0      0
# 1867  31790217  2018-12-09   42.0      0
# 1970  31850347  2018-12-09    5.0      0
# 2080  31892295  2018-12-09   15.0      0
# 2127  31916208  2018-12-09   10.0      0
# ...

# %%
# 3.dataframe for category = " jeans, trousers & leggings"
rows = df[(df.category == 'Trousers & Leggings') | (df.category == 'Jeans')]
rows
# Out:
#             id  scraped_on  price  stock  \
# 0     11915875  2018-12-09   38.0     47
# 1     13685596  2018-12-09   36.0     70
# 2     17932160  2018-12-09   36.0    102
# 5     19851933  2018-12-09   38.0     47
# 6     20504724  2018-12-09   12.0     44
# ...        ...         ...    ...    ...
# 7832  33850329  2018-12-09   36.0    134
# 7874  33874286  2018-12-09   42.0     60
# 7884  33881042  2018-12-09   25.0     62
# 7885  33881121  2018-12-09   39.0     60
# 7892  33882989  2018-12-09   36.0     57
#
#                                               image_url             category
# 0     https://images.topshop.com/i/TopShop/TS44J82EB...                Jeans
# 1     https://images.topshop.com/i/TopShop/TS26A28FB...                Jeans
# 2     https://images.topshop.com/i/TopShop/TS44L37GB...                Jeans
# 5     https://images.topshop.com/i/TopShop/TS44J18IB...                Jeans
# 6     https://images.topshop.com/i/TopShop/TS16H05IB...  Trousers & Leggings
# ...

# %%
#4. dataframe with stock value = 1
rows_1 = df[(df.stock == 1) ]
rows_1
# Out:
#             id  scraped_on  price  stock  \
# 12    21119956  2018-12-09   40.0      1
# 15    22029463  2018-12-09   24.0      1
# 20    22822235  2018-12-09    1.0      1
# 21    22822540  2018-12-09    1.0      1
# 23    22945480  2018-12-09   10.0      1
# ...        ...         ...    ...    ...
# 7290  33658876  2018-12-09   13.0      1
# 7381  33693267  2018-12-09  110.0      1
# 7542  33736339  2018-12-09   42.0      1
# 7567  33747037  2018-12-09   10.0      1
# 7636  33770237  2018-12-09   40.0      1
#
#                                               image_url               category
# 12    https://images.topshop.com/i/TopShop/TS02L31IB...                  Jeans
# 15    https://images.topshop.com/i/TopShop/TS32P19IR...                  Shoes
# 20    https://images.topshop.com/i/TopShop/TS61P32IN...        Gifts & Novelty
# 21    https://images.topshop.com/i/TopShop/TS61J73IB...              Jewellery
# ...

# %%
# 5.make id column as an index column
del df['id']
df.index.names = ["sku_id"]
df
# Out:
#         scraped_on  price  stock  \
# sku_id
# 0       2018-12-09   38.0     47
# 1       2018-12-09   36.0     70
# 2       2018-12-09   36.0    102
# 3       2018-12-09    6.0     21
# 4       2018-12-09    7.0     60
# ...            ...    ...    ...
# 7903    2018-12-09   38.0     40
# 7904    2018-12-09   20.0     10
# 7905    2018-12-09   28.0     10
# 7906    2018-12-09   24.0     10
# 7907    2018-12-09   70.0     40
#
#                                                 image_url         category
# sku_id
# 0       https://images.topshop.com/i/TopShop/TS44J82EB...            Jeans
# 1       https://images.topshop.com/i/TopShop/TS26A28FB...            Jeans
# 2       https://images.topshop.com/i/TopShop/TS44L37GB...            Jeans
# 3       https://images.topshop.com/i/TopShop/TS44T15HW...             Tops
# 4       https://images.topshop.com/i/TopShop/TS27D04HW...           Skirts
# ...                                                   ...              ...
# ...

# %%
#6. 6. dataframe without scraped_on  & image_url columns
df.drop(["scraped_on","image_url"], axis = 1)
# Out:
#         price  stock         category
# sku_id
# 0        38.0     47            Jeans
# 1        36.0     70            Jeans
# 2        36.0    102            Jeans
# 3         6.0     21             Tops
# 4         7.0     60           Skirts
# ...       ...    ...              ...
# 7903     38.0     40             Tops
# 7904     20.0     10           Beauty
# 7905     28.0     10           Beauty
# 7906     24.0     10           Beauty
# 7907     70.0     40  Jackets & Coats
#
# [7908 rows x 3 columns]

# %%
# 7.make a new column called price_mean that calculates the mean of price column and subtract that from every value in that column
df['price_mean'] = df['price'] - df['price'].mean()
df
# Out:
#         scraped_on  price  stock  \
# sku_id
# 0       2018-12-09   38.0     47
# 1       2018-12-09   36.0     70
# 2       2018-12-09   36.0    102
# 3       2018-12-09    6.0     21
# 4       2018-12-09    7.0     60
# ...            ...    ...    ...
# 7903    2018-12-09   38.0     40
# 7904    2018-12-09   20.0     10
# 7905    2018-12-09   28.0     10
# 7906    2018-12-09   24.0     10
# 7907    2018-12-09   70.0     40
#
#                                                 image_url         category  \
# sku_id
# 0       https://images.topshop.com/i/TopShop/TS44J82EB...            Jeans
# 1       https://images.topshop.com/i/TopShop/TS26A28FB...            Jeans
# 2       https://images.topshop.com/i/TopShop/TS44L37GB...            Jeans
# 3       https://images.topshop.com/i/TopShop/TS44T15HW...             Tops
# 4       https://images.topshop.com/i/TopShop/TS27D04HW...           Skirts
# ...                                                   ...              ...
# ...

# %%
# 8. for 100 datapoints chosen randomly plot price v/s stock chart. 
import matplotlib.pyplot as plt
import matplotlib

matplotlib.style.use('ggplot')

random = df.sample(n=100)
plt.bar(random['price'] , random['stock'])
plt.xlabel("price") 
plt.ylabel("stock")
# Out:
# Text(0, 0.5, 'stock')

# %%
#9. calculate num of ids in each category and draw a bar chart of that.
count = df['category'].value_counts() 
count.plot.bar()

# %%
# 10. change columns names of id to sku_id, category to article_type and save the output in an excel sheet. 

df.columns = ['scraped_on','price','stock','image_url','article_type','mean_price']
df
# Out:
#         scraped_on  price  stock  \
# sku_id
# 0       2018-12-09   38.0     47
# 1       2018-12-09   36.0     70
# 2       2018-12-09   36.0    102
# 3       2018-12-09    6.0     21
# 4       2018-12-09    7.0     60
# ...            ...    ...    ...
# 7903    2018-12-09   38.0     40
# 7904    2018-12-09   20.0     10
# 7905    2018-12-09   28.0     10
# 7906    2018-12-09   24.0     10
# 7907    2018-12-09   70.0     40
#
#                                                 image_url     article_type  \
# sku_id
# 0       https://images.topshop.com/i/TopShop/TS44J82EB...            Jeans
# 1       https://images.topshop.com/i/TopShop/TS26A28FB...            Jeans
# 2       https://images.topshop.com/i/TopShop/TS44L37GB...            Jeans
# 3       https://images.topshop.com/i/TopShop/TS44T15HW...             Tops
# 4       https://images.topshop.com/i/TopShop/TS27D04HW...           Skirts
# ...                                                   ...              ...
# ...

# %%
df.to_csv('task-1.csv')
